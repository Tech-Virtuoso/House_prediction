# %%
'''
mongodb+srv://rancho:rancho@cluster0.l2got3y.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0 
'''
# Out:
# '\nmongodb+srv://rancho:rancho@cluster0.l2got3y.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0 \n'

# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\Inside AIML\House_prediction\notebook\bank.csv')

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
data=df.to_dict(orient='records')

# %%
data
# Out:
# [{'age': 30,
#   'job': 'unemployed',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 1787,
#   'housing': 'no',
#   'loan': 'no',
#   'contact': 'cellular',
#   'day': 19,
#   'month': 'oct',
#   'duration': 79,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'age': 33,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 4789,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'cellular',
#   'day': 11,
#   'month': 'may',
#   'duration': 220,
#   'campaign': 1,
#   'pdays': 339,
#   'previous': 4,
#   'poutcome': 'failure',
#   'y': 'no'},
#  {'age': 35,
#   'job': 'management',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 1350,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'cellular',
#   'day': 16,
#   'month': 'apr',
#   'duration': 185,
#   'campaign': 1,
# ...

# %%
DB_NAME="House_Loan"
COLLECTION_NAME="Bank_data"
CONNECTION_URL="mongodb+srv://rancho:rancho@cluster0.l2got3y.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# %%
client=pymongo.MongoClient(CONNECTION_URL)
data_base=client[DB_NAME]
collection=data_base[COLLECTION_NAME]
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('66325024daae35dfbbe6d77f'), ObjectId('66325024daae35dfbbe6d780'), ObjectId('66325024daae35dfbbe6d781'), ObjectId('66325024daae35dfbbe6d782'), ObjectId('66325024daae35dfbbe6d783'), ObjectId('66325024daae35dfbbe6d784'), ObjectId('66325024daae35dfbbe6d785'), ObjectId('66325024daae35dfbbe6d786'), ObjectId('66325024daae35dfbbe6d787'), ObjectId('66325024daae35dfbbe6d788'), ObjectId('66325024daae35dfbbe6d789'), ObjectId('66325024daae35dfbbe6d78a'), ObjectId('66325024daae35dfbbe6d78b'), ObjectId('66325024daae35dfbbe6d78c'), ObjectId('66325024daae35dfbbe6d78d'), ObjectId('66325024daae35dfbbe6d78e'), ObjectId('66325024daae35dfbbe6d78f'), ObjectId('66325024daae35dfbbe6d790'), ObjectId('66325024daae35dfbbe6d791'), ObjectId('66325024daae35dfbbe6d792'), ObjectId('66325024daae35dfbbe6d793'), ObjectId('66325024daae35dfbbe6d794'), ObjectId('66325024daae35dfbbe6d795'), ObjectId('66325024daae35dfbbe6d796'), ObjectId('66325024daae35dfbbe6d797'), ObjectId('66325024daae35dfbbe6
# ...

# %%
record=collection.find()

# %%
for i,j in enumerate(record):
    print(f"{i}:{j}")
# Out:
# 0:{'_id': ObjectId('66325024daae35dfbbe6d77f'), 'age': 30, 'job': 'unemployed', 'marital': 'married', 'education': 'primary', 'default': 'no', 'balance': 1787, 'housing': 'no', 'loan': 'no', 'contact': 'cellular', 'day': 19, 'month': 'oct', 'duration': 79, 'campaign': 1, 'pdays': -1, 'previous': 0, 'poutcome': 'unknown', 'y': 'no'}
# 1:{'_id': ObjectId('66325024daae35dfbbe6d780'), 'age': 33, 'job': 'services', 'marital': 'married', 'education': 'secondary', 'default': 'no', 'balance': 4789, 'housing': 'yes', 'loan': 'yes', 'contact': 'cellular', 'day': 11, 'month': 'may', 'duration': 220, 'campaign': 1, 'pdays': 339, 'previous': 4, 'poutcome': 'failure', 'y': 'no'}
# ...

# %%
df_1=pd.DataFrame(list(collection.find()))

# %%
df_1.head()
# Out:
#                         _id  age          job  marital  education default  \
# 0  66325024daae35dfbbe6d77f   30   unemployed  married    primary      no
# 1  66325024daae35dfbbe6d780   33     services  married  secondary      no
# 2  66325024daae35dfbbe6d781   35   management   single   tertiary      no
# 3  66325024daae35dfbbe6d782   30   management  married   tertiary      no
# 4  66325024daae35dfbbe6d783   59  blue-collar  married  secondary      no
#
#    balance housing loan   contact  day month  duration  campaign  pdays  \
# 0     1787      no   no  cellular   19   oct        79         1     -1
# 1     4789     yes  yes  cellular   11   may       220         1    339
# 2     1350     yes   no  cellular   16   apr       185         1    330
# 3     1476     yes  yes   unknown    3   jun       199         4     -1
# 4        0     yes   no   unknown    5   may       226         1     -1
#
#    previous poutcome   y
# 0         0  unknown  no
# 1         4  failure  no
# ...

# %%
if "_id" in df_1.columns.to_list():
    df_1=df_1.drop(columns=["_id"],axis=1)

# %%
df_1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no
